# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
import pymysql
from sqlalchemy import create_engine, text

# %%
def combine_columns(df):
    df["String Combination"] = ('In round ' + df['round'].astype(str) + ', with a value of ' + df['clue_value'].astype(str) +
    ', a daily double value of ' + df['daily_double_value'].astype(str) + ', in the category ' + df['category'].astype(str) +
    ', the question was ' + df['answer'].astype(str) + ' and the answer was ' + df['question'].astype(str) + '. This was on ' +
    df['air_date'].astype(str) + '.')
    df.loc[df['comments'].str.contains(r"[a-zA-Z]"), 'String Combination'] += ' Comments: ' + df['comments'].astype(str) + '.'
    df.loc[df['notes'].str.contains(r"[a-zA-Z]"), 'String Combination'] += ' Notes: ' + df['notes'].astype(str) + '.'
    return df

# %%
load_dotenv()  # Load from .env file

def create_connection():
    try:
        connection = pymysql.connect(
            host=os.getenv("DB_HOST"),
            user=os.getenv("DB_USER"),
            password=os.getenv("DB_PASSWORD"),
            database = os.getenv("DB_NAME")
        )
        if connection:
            print("Connection successful!")
        return connection
    except pymysql.Error as e:
        print(f"Connection error: {e}")
        return None

def get_db_creds():
    host = os.getenv("DB_HOST")
    user = os.getenv("DB_USER")
    password = os.getenv("DB_PASSWORD")
    name = os.getenv("DB_NAME")
    table = os.getenv("TABLE_NAME")
    return host, user, password, name, table

# %%
query = "SELECT * FROM main_data LIMIT 100"

conn = create_connection()

df = pd.read_sql_query(query, conn)
# Out:
# Connection successful!
# /var/folders/zj/r53y5rb179z438lmdfg069y80000gn/T/ipykernel_97587/2568179190.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
df.head()
# Out:
#    id round clue_value daily_double_value        category comments  \
# 0   1     1        100                  0  LAKES & RIVERS
# 1   2     1        200                  0  LAKES & RIVERS
# 2   3     1        400                  0  LAKES & RIVERS
# 3   4     1        500                  0  LAKES & RIVERS
# 4   5     1        100                  0      INVENTIONS
#
#                                               answer         question  \
# 0            River mentioned most often in the Bible       the Jordan
# 1                             Scottish word for lake             loch
# 2  American river only 33 miles shorter than the ...     the Missouri
# 3  Worlds largest lake, nearly 5 times as big as ...  the Caspian Sea
# 4                        Marconis wonderful wireless          a radio
#
#      air_date notes          created_at string_combination
# 0  1984-09-10       2025-04-25 19:55:39               None
# 1  1984-09-10       2025-04-25 19:55:39               None
# 2  1984-09-10       2025-04-25 19:55:39               None
# 3  1984-09-10       2025-04-25 19:55:39               None
# 4  1984-09-10       2025-04-25 19:55:39               None

# %%
df = combine_columns(df)
print(df['String Combination'][0])
# Out:
# In round 1, with a value of 100, a daily double value of 0, in the category LAKES & RIVERS, the question was River mentioned most often in the Bible and the answer was the Jordan. This was on 1984-09-10.

# %%
host, user, password, name, table = get_db_creds()
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{name}")
with engine.connect() as connection:
    df = pd.read_sql(query, connection)

# %%
df["String Combination"] = 'In round ' + df['round'].astype(str) + ', with a value of ' + df['clue_value'].astype(str) //
    ', a daily double value of ' + df['daily_double_value'].astype(str) + ', in the category ' + df['category'].astype(str) + //
    ', the question was ' + df['answer'].astype(str) + ' and the answer was ' + df['question'].astype(str) + '. This was on ' // +
    df['air_date'].astype(str) + '.'

# %%
concat_query = "UPDATE main_data SET combination_string = CONCAT('In round ', round, ', with a value of ', clue_value, ', a daily double value of ', daily_double_value, ', in the category ', category, ', the question was ', answer, ' and the answer was ', question, '. This was on ', air_date, '. Comments: ', comments, '. Notes: ', notes, '.');"
add_column_query = "ALTER TABLE main_data ADD COLUMN combination_string TEXT;"
read_query = "SELECT * FROM main_data LIMIT 100;"

with engine.connect() as connection:
    connection.execute(text(add_column_query))
    connection.execute(text(concat_query))
    df = pd.read_sql(query, connection)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 6
#       3 read_query = "SELECT * FROM main_data LIMIT 100;"
#       5 with engine.connect() as connection:
# ----> 6     connection.execute(text(add_column_query))
#       7     connection.execute(text(concat_query))
#       8     df = pd.read_sql(query, connection)
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353     else:
#    2354         assert exc_info[1] is not None
# -> 2355         raise exc_info[1].with_traceback(exc_info[2])
#    2356 finally:
#    2357     del self._reentrant_error
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/sqlalchemy/engine/default.py:945, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     944 def do_execute(self, cursor, statement, parameters, context=None):
# --> 945     cursor.execute(statement, parameters)
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/pymysql/connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/pymysql/connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/pymysql/connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/pymysql/connections.py:744, in Connection._read_packet(self, packet_type)
#     742 buff = bytearray()
#     743 while True:
# --> 744     packet_header = self._read_bytes(4)
#     745     # if DEBUG: dump_packet(packet_header)
#     747     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File ~/Desktop/ds_prep/jeopardy_assistant/.venv/lib/python3.9/site-packages/pymysql/connections.py:782, in Connection._read_bytes(self, num_bytes)
#     780 while True:
#     781     try:
# --> 782         data = self._rfile.read(num_bytes)
#     783         break
#     784     except OSError as e:
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
connection.close()

# %%
df[df['comments'].str.contains(r"[a-zA-Z]")]
# Out:
#             id round clue_value daily_double_value  category  \
# 494        495     2        200                  0      1789
# 495        496     2        400                  0      1789
# 496        497     2       1000                  0      1789
# 507        508     2        200                  0  HOMONYMS
# 508        509     2        400                  0  HOMONYMS
# ...        ...   ...        ...                ...       ...
# 515868  515869     2        400                  0     I + 4
# 515869  515870     2        800                  0     I + 4
# 515870  515871     2       1200                  0     I + 4
# 515871  515872     2       1600                  0     I + 4
# 515872  515873     2       2000                  0     I + 4
#
#                                                  comments  \
# 494                               (Alex: ...a good year.)
# 495                               (Alex: ...a good year.)
# 496                               (Alex: ...a good year.)
# 507     (Alex: And for the benefit of our folks at hom...
# 508     (Alex: And for the benefit of our folks at hom...
# ...                                                   ...
# 515868  (Ken: I will be the first letter of these 5-le...
# 515869  (Ken: I will be the first letter of these 5-le...
# 515870  (Ken: I will be the first letter of these 5-le...
# 515871  (Ken: I will be the first letter of these 5-le...
# 515872  (Ken: I will be the first letter of these 5-le...
#
#                                                    answer  \
# 494     Washington proclaimed Nov. 26, 1789 this first...
# 495          Why April 28th was a bad day for Capt. Bligh
# 496     Now totaling over $1 trillion, it began 11 day...
# 507                     Hindu hierarchy or a plays actors
# 508                                    Near or a purchase
# ...                                                   ...
# 515868  Typically found at the end of a book, its an a...
# 515869  This Texas-based company has been making its i...
# 515870  Last name of Max, son of a famous actor father...
# 515871  William Butler Yeats got nationalistic as he u...
# 515872  In Doctor Faustus Christopher Marlowe uses thi...
#
#                                    question    air_date notes  \
# 494                            Thanksgiving  1984-09-21
# 495     the day of the mutiny on the Bounty  1984-09-21
# 496                       the national debt  1984-09-21
# 507                          a caste (cast)  1984-09-21
# 508                                by (buy)  1984-09-21
# ...                                     ...         ...   ...
# 515868                                index  2024-07-26
# 515869                                Igloo  2024-07-26
# 515870                                Irons  2024-07-26
# 515871                                Irish  2024-07-26
# 515872                                Ilium  2024-07-26
#
#                 created_at                String Combination
# 494    2025-04-25 19:55:39   In round 2, with a value of 200
# 495    2025-04-25 19:55:39   In round 2, with a value of 400
# 496    2025-04-25 19:55:39  In round 2, with a value of 1000
# 507    2025-04-25 19:55:39   In round 2, with a value of 200
# 508    2025-04-25 19:55:39   In round 2, with a value of 400
# ...                    ...                               ...
# 515868 2025-04-25 20:00:23   In round 2, with a value of 400
# 515869 2025-04-25 20:00:23   In round 2, with a value of 800
# 515870 2025-04-25 20:00:23  In round 2, with a value of 1200
# 515871 2025-04-25 20:00:23  In round 2, with a value of 1600
# 515872 2025-04-25 20:00:23  In round 2, with a value of 2000
#
# [34130 rows x 12 columns]
